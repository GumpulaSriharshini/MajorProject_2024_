# %%
import pandas as pd
import string
from string import digits
import re
import os
from numpy import array, argmax, random, take
from sklearn.model_selection import train_test_split
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Embedding, RepeatVector,TimeDistributed
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping,ReduceLROnPlateau
from tensorflow.keras.models import load_model
from tensorflow.keras import optimizers
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
english_sentances = []
telugu_sentances = []
with open("/content/drive/MyDrive/english_telugu_data.txt", mode='rt', encoding='utf-8') as fp:
    for line in fp.readlines():
        eng_tel = line.split("++++$++++")
        english_sentances.append(eng_tel[0])
        telugu_sentances.append(eng_tel[1])

# %%
data = pd.DataFrame({"english_sentances":english_sentances,"telugu_sentances":telugu_sentances})

# %%
data.head()
# Out:
#                                    english_sentances  \
# 0                                 His legs are long.
# 1                Who taught Tom how to speak French?
# 2                       I swim in the sea every day.
# 3  Tom popped into the supermarket on his way hom...
# 4                             Smoke filled the room.
#
#                                     telugu_sentances
# 0                     అతని కాళ్ళు పొడవుగా ఉన్నాయి.\n
# 1          టామ్ ఫ్రెంచ్ మాట్లాడటం ఎలా నేర్పించారు?\n
# 2            నేను ప్రతి రోజు సముద్రంలో ఈత కొడతాను.\n
# 3  టామ్ కొంచెం పాలు కొనడానికి ఇంటికి వెళ్ళేటప్పుడ...
# 4                              పొగ గదిని నింపింది.\n

# %%
data.shape
# Out:
# (155798, 2)

# %%
data = data.iloc[:70000,:]

# %%
contraction_mapping = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not",
                           "didn't": "did not",  "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not",
                           "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",
                           "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would",
                           "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would",
                           "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam",
                           "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have",
                           "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock",
                           "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have",
                           "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is",
                           "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as",
                           "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would",
                           "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have",
                           "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have",
                           "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are",
                           "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",
                           "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is",
                           "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have",
                           "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have",
                           "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all",
                           "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",
                           "you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have",
                           "you're": "you are", "you've": "you have"}

# %%
def clean_eng(text):
    text = text.lower()
    text = ' '.join([contraction_mapping[w] if w in contraction_mapping else w for w in text.split(" ")])
    text = re.sub("'", '', text)
    exclude = set(string.punctuation)
    text = ''.join([c for c in text if c not in exclude])
    remove_digits = str.maketrans('', '', digits)
    text = text.translate(remove_digits)
    text= text.strip()

    return text

# %%
def clean_tel(text):
    text = text.lower()
    text = re.sub("'", '', text)
    exclude = set(string.punctuation)
    text = ''.join([c for c in text if c not in exclude])
    remove_digits = str.maketrans('', '', digits)
    text = text.translate(remove_digits)
    text = re.sub("[౦౧౨౩౪౫౬౭౮౯]", '', text)
    text= text.strip()

    return text

# %%
data_df = data.copy()
data_df["english_sentances"] = data_df["english_sentances"] .apply(lambda x: clean_eng(x))
data_df["telugu_sentances"] = data_df["telugu_sentances"] .apply(lambda x: clean_tel(x))

# %%
data_df.head()
# Out:
#                                    english_sentances  \
# 0                                  his legs are long
# 1                 who taught tom how to speak french
# 2                        i swim in the sea every day
# 3  tom popped into the supermarket on his way hom...
# 4                              smoke filled the room
#
#                                     telugu_sentances
# 0                        అతని కాళ్ళు పొడవుగా ఉన్నాయి
# 1             టామ్ ఫ్రెంచ్ మాట్లాడటం ఎలా నేర్పించారు
# 2               నేను ప్రతి రోజు సముద్రంలో ఈత కొడతాను
# 3  టామ్ కొంచెం పాలు కొనడానికి ఇంటికి వెళ్ళేటప్పుడ...
# 4                                 పొగ గదిని నింపింది

# %%
# empty lists
eng_l = []
tel_l = []

for i in data_df["english_sentances"].values:
      eng_l.append(len(i.split()))

for i in data_df["telugu_sentances"].values:
      tel_l.append(len(i.split()))

length_df = pd.DataFrame({'eng':eng_l, 'tel':tel_l})

length_df.hist(bins = 30)
plt.show()

# %%
def tokenization(lines):
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(lines)
    return tokenizer

# %%
eng_tokenizer = tokenization(data_df["english_sentances"])
eng_vocab_size = len(eng_tokenizer.word_index) + 1

eng_length = 43
print('English Vocabulary Size: %d' % eng_vocab_size)
# Out:
# English Vocabulary Size: 10315

# %%
tel_tokenizer = tokenization(data_df["telugu_sentances"])
tel_vocab_size = len(tel_tokenizer.word_index) + 1

tel_length = 26
print('Telugu Vocabulary Size: %d' % tel_vocab_size)
# Out:
# Telugu Vocabulary Size: 26680

# %%
def encode_sequences(tokenizer, length, lines):
    seq = tokenizer.texts_to_sequences(lines)
    seq = pad_sequences(seq, maxlen=length, padding='post')
    return seq

# %%
train, test = train_test_split(data_df, test_size=0.2, random_state = 12)

# %%
trainX = encode_sequences(eng_tokenizer, eng_length, train["english_sentances"])
trainY = encode_sequences(tel_tokenizer, tel_length, train["telugu_sentances"])

testX = encode_sequences(eng_tokenizer, eng_length, test["english_sentances"])
testY = encode_sequences(tel_tokenizer, tel_length, test["telugu_sentances"])

# %%
trainX
# Out:
# array([[   1,   34,   12, ...,    0,    0,    0],
#        [   1,  340,    3, ...,    0,    0,    0],
#        [  12,    7,   38, ...,    0,    0,    0],
#        ...,
#        [  15, 1161,   20, ...,    0,    0,    0],
#        [  10,    7,   24, ...,    0,    0,    0],
#        [   2,  152,   11, ...,    0,    0,    0]], dtype=int32)

# %%
trainX.shape,trainY.shape,testX.shape,testY.shape
# Out:
# ((56000, 43), (56000, 26), (14000, 43), (14000, 26))

# %%
def define_model(in_vocab,out_vocab, in_timesteps,out_timesteps,units):
    model = Sequential()
    model.add(Embedding(in_vocab, units, input_length=in_timesteps, mask_zero=True))
    model.add(LSTM(units))
    model.add(RepeatVector(out_timesteps))
    model.add(LSTM(units, return_sequences=True))
    model.add(TimeDistributed(Dense(out_vocab, activation='softmax')))
    return model

# %%
model = define_model(eng_vocab_size,tel_vocab_size,eng_length,tel_length, 512)
model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ repeat_vector (RepeatVector)         │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed (TimeDistributed)   │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
rms = optimizers.RMSprop()
model.compile(optimizer=rms, loss='sparse_categorical_crossentropy')

# %%
filepath = '/content/drive/MyDrive/English to telugu'+'NMT.keras'
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
reduce_alpha = ReduceLROnPlateau(monitor ='val_loss', factor = 0.2, patience = 1, min_lr = 0.001)
callbacks = [checkpoint, reduce_alpha]

# %%
history = model.fit(trainX, trainY.reshape(trainY.shape[0], trainY.shape[1], 1),
                    epochs=100, batch_size=128, validation_split = 0.2,callbacks=callbacks, verbose=1)
# Out:
# Epoch 1/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - loss: 2.3582
# Epoch 1: val_loss improved from inf to 1.33554, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 95s 236ms/step - loss: 2.3561 - val_loss: 1.3355 - learning_rate: 0.0010
# Epoch 2/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - loss: 1.3202
# Epoch 2: val_loss improved from 1.33554 to 1.31363, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 126s 212ms/step - loss: 1.3202 - val_loss: 1.3136 - learning_rate: 0.0010
# Epoch 3/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 1.2991
# Epoch 3: val_loss improved from 1.31363 to 1.30150, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 76s 216ms/step - loss: 1.2990 - val_loss: 1.3015 - learning_rate: 0.0010
# Epoch 4/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 1.2820
# Epoch 4: val_loss improved from 1.30150 to 1.29531, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 76s 216ms/step - loss: 1.2820 - val_loss: 1.2953 - learning_rate: 0.0010
# Epoch 5/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 1.2684
# Epoch 5: val_loss did not improve from 1.29531
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 81s 214ms/step - loss: 1.2684 - val_loss: 1.3162 - learning_rate: 0.0010
# Epoch 6/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 1.2650
# Epoch 6: val_loss did not improve from 1.29531
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 75s 213ms/step - loss: 1.2650 - val_loss: 1.3044 - learning_rate: 0.0010
# Epoch 7/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 1.2463
# Epoch 7: val_loss improved from 1.29531 to 1.26146, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 83s 217ms/step - loss: 1.2463 - val_loss: 1.2615 - learning_rate: 0.0010
# Epoch 8/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 1.2310
# Epoch 8: val_loss improved from 1.26146 to 1.25582, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 82s 217ms/step - loss: 1.2310 - val_loss: 1.2558 - learning_rate: 0.0010
# Epoch 9/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 1.2193
# Epoch 9: val_loss improved from 1.25582 to 1.24279, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 82s 217ms/step - loss: 1.2193 - val_loss: 1.2428 - learning_rate: 0.0010
# Epoch 10/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 1.2010
# Epoch 10: val_loss improved from 1.24279 to 1.22050, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 82s 217ms/step - loss: 1.2010 - val_loss: 1.2205 - learning_rate: 0.0010
# Epoch 11/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 1.1851
# Epoch 11: val_loss improved from 1.22050 to 1.20485, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 82s 217ms/step - loss: 1.1851 - val_loss: 1.2049 - learning_rate: 0.0010
# Epoch 12/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 1.1687
# Epoch 12: val_loss improved from 1.20485 to 1.19187, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 82s 218ms/step - loss: 1.1687 - val_loss: 1.1919 - learning_rate: 0.0010
# Epoch 13/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 1.1475
# Epoch 13: val_loss improved from 1.19187 to 1.18127, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 82s 217ms/step - loss: 1.1475 - val_loss: 1.1813 - learning_rate: 0.0010
# Epoch 14/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 1.1336
# Epoch 14: val_loss improved from 1.18127 to 1.17906, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 76s 218ms/step - loss: 1.1336 - val_loss: 1.1791 - learning_rate: 0.0010
# Epoch 15/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 1.1195
# Epoch 15: val_loss improved from 1.17906 to 1.16117, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 82s 217ms/step - loss: 1.1195 - val_loss: 1.1612 - learning_rate: 0.0010
# Epoch 16/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 1.1065
# Epoch 16: val_loss improved from 1.16117 to 1.14252, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 76s 217ms/step - loss: 1.1065 - val_loss: 1.1425 - learning_rate: 0.0010
# Epoch 17/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 1.0905
# Epoch 17: val_loss improved from 1.14252 to 1.13392, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 76s 217ms/step - loss: 1.0905 - val_loss: 1.1339 - learning_rate: 0.0010
# Epoch 18/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 1.0816
# Epoch 18: val_loss improved from 1.13392 to 1.12954, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 76s 217ms/step - loss: 1.0816 - val_loss: 1.1295 - learning_rate: 0.0010
# Epoch 19/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 1.0640
# Epoch 19: val_loss improved from 1.12954 to 1.11914, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 76s 218ms/step - loss: 1.0640 - val_loss: 1.1191 - learning_rate: 0.0010
# Epoch 20/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 1.0526
# Epoch 20: val_loss improved from 1.11914 to 1.10549, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 82s 218ms/step - loss: 1.0526 - val_loss: 1.1055 - learning_rate: 0.0010
# Epoch 21/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 1.0365
# Epoch 21: val_loss improved from 1.10549 to 1.09657, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 82s 218ms/step - loss: 1.0365 - val_loss: 1.0966 - learning_rate: 0.0010
# Epoch 22/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - loss: 1.0266
# Epoch 22: val_loss improved from 1.09657 to 1.08822, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 82s 218ms/step - loss: 1.0266 - val_loss: 1.0882 - learning_rate: 0.0010
# Epoch 23/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 1.0162
# Epoch 23: val_loss improved from 1.08822 to 1.07458, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 76s 217ms/step - loss: 1.0162 - val_loss: 1.0746 - learning_rate: 0.0010
# Epoch 24/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 1.0071
# Epoch 24: val_loss did not improve from 1.07458
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 75s 215ms/step - loss: 1.0071 - val_loss: 1.0764 - learning_rate: 0.0010
# Epoch 25/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.9919
# Epoch 25: val_loss improved from 1.07458 to 1.05737, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 83s 217ms/step - loss: 0.9919 - val_loss: 1.0574 - learning_rate: 0.0010
# Epoch 26/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.9766
# Epoch 26: val_loss improved from 1.05737 to 1.04438, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 82s 218ms/step - loss: 0.9766 - val_loss: 1.0444 - learning_rate: 0.0010
# Epoch 27/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - loss: 0.9649
# Epoch 27: val_loss improved from 1.04438 to 1.03718, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 82s 218ms/step - loss: 0.9649 - val_loss: 1.0372 - learning_rate: 0.0010
# Epoch 28/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.9517
# Epoch 28: val_loss improved from 1.03718 to 1.02608, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 82s 218ms/step - loss: 0.9517 - val_loss: 1.0261 - learning_rate: 0.0010
# Epoch 29/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.9404
# Epoch 29: val_loss improved from 1.02608 to 1.02277, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 76s 217ms/step - loss: 0.9404 - val_loss: 1.0228 - learning_rate: 0.0010
# Epoch 30/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.9219
# Epoch 30: val_loss improved from 1.02277 to 1.00810, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 76s 217ms/step - loss: 0.9219 - val_loss: 1.0081 - learning_rate: 0.0010
# Epoch 31/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.9164
# Epoch 31: val_loss improved from 1.00810 to 1.00545, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 82s 218ms/step - loss: 0.9164 - val_loss: 1.0055 - learning_rate: 0.0010
# Epoch 32/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.8991
# Epoch 32: val_loss improved from 1.00545 to 0.99628, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 82s 218ms/step - loss: 0.8992 - val_loss: 0.9963 - learning_rate: 0.0010
# Epoch 33/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.8799
# Epoch 33: val_loss improved from 0.99628 to 0.98284, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 82s 218ms/step - loss: 0.8799 - val_loss: 0.9828 - learning_rate: 0.0010
# Epoch 34/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.8769
# Epoch 34: val_loss improved from 0.98284 to 0.98044, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 76s 218ms/step - loss: 0.8769 - val_loss: 0.9804 - learning_rate: 0.0010
# Epoch 35/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - loss: 0.8628
# Epoch 35: val_loss improved from 0.98044 to 0.96622, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 82s 218ms/step - loss: 0.8628 - val_loss: 0.9662 - learning_rate: 0.0010
# Epoch 36/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.8535
# Epoch 36: val_loss improved from 0.96622 to 0.95979, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 76s 218ms/step - loss: 0.8535 - val_loss: 0.9598 - learning_rate: 0.0010
# Epoch 37/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.8418
# Epoch 37: val_loss improved from 0.95979 to 0.95169, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 82s 218ms/step - loss: 0.8418 - val_loss: 0.9517 - learning_rate: 0.0010
# Epoch 38/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - loss: 0.8281
# Epoch 38: val_loss improved from 0.95169 to 0.94616, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 82s 219ms/step - loss: 0.8281 - val_loss: 0.9462 - learning_rate: 0.0010
# Epoch 39/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - loss: 0.8181
# Epoch 39: val_loss improved from 0.94616 to 0.94576, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 82s 218ms/step - loss: 0.8181 - val_loss: 0.9458 - learning_rate: 0.0010
# Epoch 40/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - loss: 0.8047
# Epoch 40: val_loss did not improve from 0.94576
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 81s 215ms/step - loss: 0.8047 - val_loss: 0.9466 - learning_rate: 0.0010
# Epoch 41/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - loss: 0.7977
# Epoch 41: val_loss improved from 0.94576 to 0.92600, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 83s 218ms/step - loss: 0.7977 - val_loss: 0.9260 - learning_rate: 0.0010
# Epoch 42/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - loss: 0.7877
# Epoch 42: val_loss improved from 0.92600 to 0.91811, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 82s 218ms/step - loss: 0.7877 - val_loss: 0.9181 - learning_rate: 0.0010
# Epoch 43/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - loss: 0.7763
# Epoch 43: val_loss did not improve from 0.91811
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 81s 215ms/step - loss: 0.7764 - val_loss: 0.9191 - learning_rate: 0.0010
# Epoch 44/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - loss: 0.7667
# Epoch 44: val_loss improved from 0.91811 to 0.90558, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 76s 218ms/step - loss: 0.7667 - val_loss: 0.9056 - learning_rate: 0.0010
# Epoch 45/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - loss: 0.7565
# Epoch 45: val_loss improved from 0.90558 to 0.90422, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 82s 219ms/step - loss: 0.7565 - val_loss: 0.9042 - learning_rate: 0.0010
# Epoch 46/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - loss: 0.7471
# Epoch 46: val_loss improved from 0.90422 to 0.90048, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 76s 218ms/step - loss: 0.7471 - val_loss: 0.9005 - learning_rate: 0.0010
# Epoch 47/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.7337
# Epoch 47: val_loss improved from 0.90048 to 0.89118, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 82s 219ms/step - loss: 0.7337 - val_loss: 0.8912 - learning_rate: 0.0010
# Epoch 48/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - loss: 0.7254
# Epoch 48: val_loss improved from 0.89118 to 0.89088, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 76s 218ms/step - loss: 0.7254 - val_loss: 0.8909 - learning_rate: 0.0010
# Epoch 49/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - loss: 0.7187
# Epoch 49: val_loss improved from 0.89088 to 0.88193, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 82s 219ms/step - loss: 0.7187 - val_loss: 0.8819 - learning_rate: 0.0010
# Epoch 50/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - loss: 0.7071
# Epoch 50: val_loss did not improve from 0.88193
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 81s 215ms/step - loss: 0.7071 - val_loss: 0.8838 - learning_rate: 0.0010
# Epoch 51/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - loss: 0.6977
# Epoch 51: val_loss improved from 0.88193 to 0.87283, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 83s 218ms/step - loss: 0.6977 - val_loss: 0.8728 - learning_rate: 0.0010
# Epoch 52/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - loss: 0.6878
# Epoch 52: val_loss did not improve from 0.87283
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 81s 215ms/step - loss: 0.6878 - val_loss: 0.8778 - learning_rate: 0.0010
# Epoch 53/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - loss: 0.6814
# Epoch 53: val_loss improved from 0.87283 to 0.86596, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 87s 230ms/step - loss: 0.6814 - val_loss: 0.8660 - learning_rate: 0.0010
# Epoch 54/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - loss: 0.6717
# Epoch 54: val_loss improved from 0.86596 to 0.86183, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 78s 219ms/step - loss: 0.6717 - val_loss: 0.8618 - learning_rate: 0.0010
# Epoch 55/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - loss: 0.6590
# Epoch 55: val_loss improved from 0.86183 to 0.86144, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 82s 218ms/step - loss: 0.6590 - val_loss: 0.8614 - learning_rate: 0.0010
# Epoch 56/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - loss: 0.6543
# Epoch 56: val_loss improved from 0.86144 to 0.85809, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 76s 219ms/step - loss: 0.6543 - val_loss: 0.8581 - learning_rate: 0.0010
# Epoch 57/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - loss: 0.6401
# Epoch 57: val_loss improved from 0.85809 to 0.85255, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 82s 219ms/step - loss: 0.6402 - val_loss: 0.8526 - learning_rate: 0.0010
# Epoch 58/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - loss: 0.6320
# Epoch 58: val_loss improved from 0.85255 to 0.85165, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 76s 218ms/step - loss: 0.6320 - val_loss: 0.8517 - learning_rate: 0.0010
# Epoch 59/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - loss: 0.6267
# Epoch 59: val_loss improved from 0.85165 to 0.84534, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 76s 218ms/step - loss: 0.6267 - val_loss: 0.8453 - learning_rate: 0.0010
# Epoch 60/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - loss: 0.6158
# Epoch 60: val_loss did not improve from 0.84534
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 81s 215ms/step - loss: 0.6158 - val_loss: 0.8469 - learning_rate: 0.0010
# Epoch 61/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - loss: 0.6057
# Epoch 61: val_loss improved from 0.84534 to 0.84125, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 83s 219ms/step - loss: 0.6057 - val_loss: 0.8412 - learning_rate: 0.0010
# Epoch 62/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - loss: 0.6013
# Epoch 62: val_loss improved from 0.84125 to 0.83776, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 82s 218ms/step - loss: 0.6013 - val_loss: 0.8378 - learning_rate: 0.0010
# Epoch 63/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - loss: 0.5939
# Epoch 63: val_loss did not improve from 0.83776
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 81s 216ms/step - loss: 0.5939 - val_loss: 0.8416 - learning_rate: 0.0010
# Epoch 64/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - loss: 0.5867
# Epoch 64: val_loss improved from 0.83776 to 0.83445, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 83s 218ms/step - loss: 0.5867 - val_loss: 0.8344 - learning_rate: 0.0010
# Epoch 65/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - loss: 0.5731
# Epoch 65: val_loss improved from 0.83445 to 0.83225, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 82s 218ms/step - loss: 0.5731 - val_loss: 0.8323 - learning_rate: 0.0010
# Epoch 66/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - loss: 0.5707
# Epoch 66: val_loss improved from 0.83225 to 0.82956, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 83s 220ms/step - loss: 0.5707 - val_loss: 0.8296 - learning_rate: 0.0010
# Epoch 67/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - loss: 0.5575
# Epoch 67: val_loss did not improve from 0.82956
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 80s 216ms/step - loss: 0.5576 - val_loss: 0.8305 - learning_rate: 0.0010
# Epoch 68/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - loss: 0.5510
# Epoch 68: val_loss improved from 0.82956 to 0.82790, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 83s 218ms/step - loss: 0.5510 - val_loss: 0.8279 - learning_rate: 0.0010
# Epoch 69/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - loss: 0.5410
# Epoch 69: val_loss improved from 0.82790 to 0.82371, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 82s 219ms/step - loss: 0.5411 - val_loss: 0.8237 - learning_rate: 0.0010
# Epoch 70/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - loss: 0.5357
# Epoch 70: val_loss did not improve from 0.82371
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 81s 215ms/step - loss: 0.5357 - val_loss: 0.8286 - learning_rate: 0.0010
# Epoch 71/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - loss: 0.5292
# Epoch 71: val_loss did not improve from 0.82371
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 82s 215ms/step - loss: 0.5292 - val_loss: 0.8254 - learning_rate: 0.0010
# Epoch 72/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.5202
# Epoch 72: val_loss improved from 0.82371 to 0.82181, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 76s 217ms/step - loss: 0.5202 - val_loss: 0.8218 - learning_rate: 0.0010
# Epoch 73/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.5106
# Epoch 73: val_loss improved from 0.82181 to 0.82025, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 76s 217ms/step - loss: 0.5106 - val_loss: 0.8202 - learning_rate: 0.0010
# Epoch 74/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.5094
# Epoch 74: val_loss improved from 0.82025 to 0.81936, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 82s 217ms/step - loss: 0.5094 - val_loss: 0.8194 - learning_rate: 0.0010
# Epoch 75/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.5001
# Epoch 75: val_loss improved from 0.81936 to 0.81749, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 82s 217ms/step - loss: 0.5001 - val_loss: 0.8175 - learning_rate: 0.0010
# Epoch 76/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.4948
# Epoch 76: val_loss improved from 0.81749 to 0.81683, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 76s 217ms/step - loss: 0.4948 - val_loss: 0.8168 - learning_rate: 0.0010
# Epoch 77/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.4854
# Epoch 77: val_loss improved from 0.81683 to 0.81623, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 77s 219ms/step - loss: 0.4854 - val_loss: 0.8162 - learning_rate: 0.0010
# Epoch 78/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.4739
# Epoch 78: val_loss did not improve from 0.81623
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 80s 214ms/step - loss: 0.4739 - val_loss: 0.8209 - learning_rate: 0.0010
# Epoch 79/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.4706
# Epoch 79: val_loss did not improve from 0.81623
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 82s 214ms/step - loss: 0.4706 - val_loss: 0.8213 - learning_rate: 0.0010
# Epoch 80/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - loss: 0.4620
# Epoch 80: val_loss did not improve from 0.81623
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 82s 213ms/step - loss: 0.4621 - val_loss: 0.8175 - learning_rate: 0.0010
# Epoch 81/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - loss: 0.4550
# Epoch 81: val_loss improved from 0.81623 to 0.81590, saving model to /content/drive/MyDrive/English to teluguNMT.keras
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 83s 215ms/step - loss: 0.4550 - val_loss: 0.8159 - learning_rate: 0.0010
# Epoch 82/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - loss: 0.4507
# Epoch 82: val_loss did not improve from 0.81590
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 74s 212ms/step - loss: 0.4507 - val_loss: 0.8167 - learning_rate: 0.0010
# Epoch 83/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - loss: 0.4409
# Epoch 83: val_loss did not improve from 0.81590
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 74s 211ms/step - loss: 0.4409 - val_loss: 0.8178 - learning_rate: 0.0010
# Epoch 84/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - loss: 0.4341
# Epoch 84: val_loss did not improve from 0.81590
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 82s 211ms/step - loss: 0.4341 - val_loss: 0.8183 - learning_rate: 0.0010
# Epoch 85/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - loss: 0.4313
# Epoch 85: val_loss did not improve from 0.81590
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 82s 211ms/step - loss: 0.4313 - val_loss: 0.8239 - learning_rate: 0.0010
# Epoch 86/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - loss: 0.4226
# Epoch 86: val_loss did not improve from 0.81590
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 82s 210ms/step - loss: 0.4226 - val_loss: 0.8257 - learning_rate: 0.0010
# Epoch 87/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - loss: 0.4175
# Epoch 87: val_loss did not improve from 0.81590
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 82s 210ms/step - loss: 0.4175 - val_loss: 0.8166 - learning_rate: 0.0010
# Epoch 88/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - loss: 0.4081
# Epoch 88: val_loss did not improve from 0.81590
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 82s 209ms/step - loss: 0.4081 - val_loss: 0.8177 - learning_rate: 0.0010
# Epoch 89/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - loss: 0.3999
# Epoch 89: val_loss did not improve from 0.81590
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 82s 209ms/step - loss: 0.3999 - val_loss: 0.8222 - learning_rate: 0.0010
# Epoch 90/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - loss: 0.3974
# Epoch 90: val_loss did not improve from 0.81590
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 82s 209ms/step - loss: 0.3975 - val_loss: 0.8262 - learning_rate: 0.0010
# Epoch 91/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - loss: 0.3922
# Epoch 91: val_loss did not improve from 0.81590
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 73s 208ms/step - loss: 0.3922 - val_loss: 0.8189 - learning_rate: 0.0010
# Epoch 92/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - loss: 0.3823
# Epoch 92: val_loss did not improve from 0.81590
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 82s 209ms/step - loss: 0.3823 - val_loss: 0.8197 - learning_rate: 0.0010
# Epoch 93/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - loss: 0.3764
# Epoch 93: val_loss did not improve from 0.81590
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 73s 208ms/step - loss: 0.3764 - val_loss: 0.8236 - learning_rate: 0.0010
# Epoch 94/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - loss: 0.3696
# Epoch 94: val_loss did not improve from 0.81590
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 82s 208ms/step - loss: 0.3696 - val_loss: 0.8199 - learning_rate: 0.0010
# Epoch 95/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - loss: 0.3656
# Epoch 95: val_loss did not improve from 0.81590
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 82s 208ms/step - loss: 0.3656 - val_loss: 0.8266 - learning_rate: 0.0010
# Epoch 96/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - loss: 0.3580
# Epoch 96: val_loss did not improve from 0.81590
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 82s 208ms/step - loss: 0.3580 - val_loss: 0.8237 - learning_rate: 0.0010
# Epoch 97/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - loss: 0.3531
# Epoch 97: val_loss did not improve from 0.81590
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 73s 208ms/step - loss: 0.3531 - val_loss: 0.8240 - learning_rate: 0.0010
# Epoch 98/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - loss: 0.3436
# Epoch 98: val_loss did not improve from 0.81590
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 73s 208ms/step - loss: 0.3436 - val_loss: 0.8334 - learning_rate: 0.0010
# Epoch 99/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - loss: 0.3398
# Epoch 99: val_loss did not improve from 0.81590
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 82s 207ms/step - loss: 0.3398 - val_loss: 0.8289 - learning_rate: 0.0010
# Epoch 100/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - loss: 0.3349
# Epoch 100: val_loss did not improve from 0.81590
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 82s 207ms/step - loss: 0.3350 - val_loss: 0.8301 - learning_rate: 0.0010

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['train','validation'])
plt.show()
